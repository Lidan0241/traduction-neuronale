# %%
# !pip3 install torch torchvision
# !pip install --upgrade gensim
# !pip install numpy

# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py
# !pip install -r OpenNMT-py/requirements.opt.txt

# %%
# !pip install OpenNMT-py

# %%
# !onmt_build_vocab -config toy_en_fr.yaml -n_sample 100000

# %%
# !onmt_train -config toy_en_fr.yaml
# Out:
# [2024-05-31 19:03:19,412 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2024-05-31 19:03:19,412 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-05-31 19:03:19,412 INFO] Missing transforms field for valid data, set to default: [].
# [2024-05-31 19:03:19,412 INFO] Parsed 2 corpora from -data.
# [2024-05-31 19:03:19,412 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2024-05-31 19:03:19,517 INFO] The first 10 tokens of the vocabs are:['<unk>', '<blank>', '<s>', '</s>', 'the', ',', 'be', '.', 'of', 'to']
# [2024-05-31 19:03:19,518 INFO] The decoder start token is: <s>
# [2024-05-31 19:03:19,518 INFO] Building model...
# [2024-05-31 19:03:20,354 INFO] Switching model to float32 for amp/apex_amp
# [2024-05-31 19:03:20,354 INFO] Non quantized layer compute is fp32
# [2024-05-31 19:03:20,533 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
# ...

# %%
# !onmt_translate -model combined_lemme_model_step_1000.pt -src combined_test_lemme.en -output combined_lemme_pred.fr -gpu 0 -verbose
# Out:
# [2024-05-31 19:05:45,134 INFO] Loading checkpoint from combined_lemme_model_step_1000.pt
# [2024-05-31 19:05:45,775 INFO] Loading data into the model
# [2024-05-31 19:05:48,894 INFO]
# SENT 1: ['finally', ',', 'voluntary', 'code', 'do', 'have', 'a', 'role', ',', 'and', 'reach', 'part', 'which', 'we', 'can', 'not', 'regulate', '.']
# PRED 1: en effet , la commission ne pouvoir pas faire la commission à la commission .
# PRED SCORE: -1.5470
#
# [2024-05-31 19:05:48,895 INFO]
# SENT 2: ['the', 'recent', 'bomb', 'attack', 'carry', 'out', 'in', 'the', 'suburb', 'of', 'Pristina', 'by', 'Albanian-speaking', 'group', 'and', 'the', 'clash', 'in', '<unk>', 'Bosnia', 'between', 'Muslims', 'and', 'Bosnian', 'Serbs', 'be', 'revive', 'source', 'of', 'tension', 'and', 'give', 'justifiable', 'cause', 'for', 'concern', 'that', 'the', 'region', 'be', 'once', 'more', 'about', 'to', 'erupt', '.']
# ...

# %%
# Combiner les 2 corpus Europarl et EMEA
'''
file1_path = 'Europarl_test_500_lemme.en'
file2_path = 'Emea_test_500_lemme.en'
output_path = 'combined_test_lemme.en'

with open(output_path, 'w') as output_file:
    for file_path in [file1_path, file2_path]:
        with open(file_path, 'r') as input_file:
            output_file.write(input_file.read())
            output_file.write("\n")
'''
# Out:
# '\nfile1_path = \'Europarl_test_500_lemme.en\'\nfile2_path = \'Emea_test_500_lemme.en\'\noutput_path = \'combined_test_lemme.en\'\n\nwith open(output_path, \'w\') as output_file:\n    for file_path in [file1_path, file2_path]:\n        with open(file_path, \'r\') as input_file:\n            output_file.write(input_file.read())\n            output_file.write("\n")\n'
