# %%
# !pip3 install torch torchvision
# !pip install --upgrade gensim
# !pip install numpy
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.18.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.40)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)

# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py
# !pip install -r OpenNMT-py/requirements.opt.txt
# Out:
# fatal: destination path 'OpenNMT-py' already exists and is not an empty directory.
# Requirement already satisfied: pyrouge in /usr/local/lib/python3.10/dist-packages (from -r OpenNMT-py/requirements.opt.txt (line 1)) (0.1.3)
# Requirement already satisfied: sentencepiece<0.1.98,>=0.1.94 in /usr/local/lib/python3.10/dist-packages (from -r OpenNMT-py/requirements.opt.txt (line 2)) (0.1.97)
# Requirement already satisfied: subword-nmt>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from -r OpenNMT-py/requirements.opt.txt (line 3)) (0.3.8)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from -r OpenNMT-py/requirements.opt.txt (line 4)) (3.9.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from -r OpenNMT-py/requirements.opt.txt (line 5)) (1.11.4)
# Requirement already satisfied: bitsandbytes>=0.41.2 in /usr/local/lib/python3.10/dist-packages (from -r OpenNMT-py/requirements.opt.txt (line 6)) (0.43.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from -r OpenNMT-py/requirements.opt.txt (line 7)) (0.4.3)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from -r OpenNMT-py/requirements.opt.txt (line 8)) (3.7.4)
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (from -r OpenNMT-py/requirements.opt.txt (line 9)) (4.26.0)
# Requirement already satisfied: mock in /usr/local/lib/python3.10/dist-packages (from subword-nmt>=0.3.7->-r OpenNMT-py/requirements.opt.txt (line 3)) (5.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from subword-nmt>=0.3.7->-r OpenNMT-py/requirements.opt.txt (line 3)) (4.66.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->-r OpenNMT-py/requirements.opt.txt (line 5)) (1.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (2.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (6.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (3.4.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (4.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.110.3)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.3.2)
# Requirement already satisfied: gradio-client==0.15.1 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.15.1)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.23.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (6.4.0)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (3.7.1)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (3.10.3)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (9.4.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.4.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.12.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (4.11.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.30.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.15.1->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (2023.6.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.15.1->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (11.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.12.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (3.14.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (2.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (13.7.1)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (0.16.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.37.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (3.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (12.5.40)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (0.18.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (1.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer<0.10.0,>=0.3.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer<0.10.0,>=0.3.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (2.16.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio->-r OpenNMT-py/requirements.opt.txt (line 9)) (1.2.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes>=0.41.2->-r OpenNMT-py/requirements.opt.txt (line 6)) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer<0.10.0,>=0.3.0->spacy->-r OpenNMT-py/requirements.opt.txt (line 8)) (0.1.2)

# %%
# !pip install OpenNMT-py
# Out:
# Requirement already satisfied: OpenNMT-py in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Collecting torch<2.3,>=2.1 (from OpenNMT-py)
#   Using cached torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
# Requirement already satisfied: configargparse in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (1.7)
# Requirement already satisfied: ctranslate2<5,>=4 in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (4.2.1)
# Requirement already satisfied: tensorboard>=2.3 in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (2.15.2)
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (2.2.5)
# Requirement already satisfied: waitress in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (3.0.0)
# Requirement already satisfied: pyonmttok<2,>=1.37 in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (1.37.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (6.0.1)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (2.4.2)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (3.9.2)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (2.1.0)
# Requirement already satisfied: fasttext-wheel in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (0.9.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (3.7.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from OpenNMT-py) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from ctranslate2<5,>=4->OpenNMT-py) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ctranslate2<5,>=4->OpenNMT-py) (1.25.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.64.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.3->OpenNMT-py) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.3->OpenNMT-py) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.3->OpenNMT-py) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.3->OpenNMT-py) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.3->OpenNMT-py) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.3->OpenNMT-py) (3.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.0.106)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch<2.3,>=2.1->OpenNMT-py)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.3,>=2.1->OpenNMT-py) (12.1.105)
# Collecting triton==2.2.0 (from torch<2.3,>=2.1->OpenNMT-py)
#   Using cached triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.3,>=2.1->OpenNMT-py) (12.5.40)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.10/dist-packages (from fasttext-wheel->OpenNMT-py) (2.12.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask->OpenNMT-py) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask->OpenNMT-py) (8.1.7)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu->OpenNMT-py) (2.8.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu->OpenNMT-py) (2024.5.15)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu->OpenNMT-py) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu->OpenNMT-py) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu->OpenNMT-py) (4.9.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (4.66.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (2.7.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->OpenNMT-py) (3.4.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.3->OpenNMT-py) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<2.3,>=2.1->OpenNMT-py) (2.1.5)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy->OpenNMT-py) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->OpenNMT-py) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->OpenNMT-py) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.3->OpenNMT-py) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.3->OpenNMT-py) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.3->OpenNMT-py) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.3->OpenNMT-py) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->OpenNMT-py) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->OpenNMT-py) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy->OpenNMT-py) (0.16.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<2.3,>=2.1->OpenNMT-py) (1.3.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->OpenNMT-py) (1.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.3->OpenNMT-py) (3.2.2)
# Installing collected packages: triton, nvidia-nccl-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.0
#     Uninstalling triton-2.3.0:
#       Successfully uninstalled triton-2.3.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.20.5
#     Uninstalling nvidia-nccl-cu12-2.20.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.20.5
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0
#     Uninstalling torch-2.3.0:
#       Successfully uninstalled torch-2.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.3.0+cu121 requires torch==2.3.0, but you have torch 2.2.2 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 2.2.2 which is incompatible.
# torchvision 0.18.0+cu121 requires torch==2.3.0, but you have torch 2.2.2 which is incompatible.
# Successfully installed nvidia-nccl-cu12-2.19.3 torch-2.2.2 triton-2.2.0

# %%
# !onmt_build_vocab -config toy_en_de.yaml -n_sample 100000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-05-30 16:40:43,791 INFO] Counter vocab from 100000 samples.
# [2024-05-30 16:40:43,791 INFO] Build vocab on 100000 transformed examples/corpus.
# [2024-05-30 16:40:48,120 INFO] Counters src: 62751
# [2024-05-30 16:40:48,120 INFO] Counters tgt: 80453

# %%
# !onmt_train -config toy_en_de.yaml
# Out:
# [2024-05-30 16:46:05,281 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2024-05-30 16:46:05,281 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-05-30 16:46:05,281 INFO] Missing transforms field for valid data, set to default: [].
# [2024-05-30 16:46:05,281 INFO] Parsed 2 corpora from -data.
# [2024-05-30 16:46:05,281 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2024-05-30 16:46:05,525 INFO] The first 10 tokens of the vocabs are:['<unk>', '<blank>', '<s>', '</s>', 'the', 'of', 'to', 'and', 'in', 'is']
# [2024-05-30 16:46:05,525 INFO] The decoder start token is: <s>
# [2024-05-30 16:46:05,525 INFO] Building model...
# [2024-05-30 16:46:06,388 INFO] Switching model to float32 for amp/apex_amp
# [2024-05-30 16:46:06,388 INFO] Non quantized layer compute is fp32
# [2024-05-30 16:46:06,568 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(32768, 500, padding_idx=1)
#         )
#       )
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (rnn): LSTM(500, 500, num_layers=2, batch_first=True, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(32768, 500, padding_idx=1)
#         )
#       )
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (dropout): Dropout(p=0.3, inplace=False)
#     (rnn): StackedLSTM(
#       (dropout): Dropout(p=0.3, inplace=False)
#       (layers): ModuleList(
#         (0): LSTMCell(1000, 500)
#         (1): LSTMCell(500, 500)
#       )
#     )
#     (attn): GlobalAttention(
#       (linear_in): Linear(in_features=500, out_features=500, bias=False)
#       (linear_out): Linear(in_features=1000, out_features=500, bias=False)
#     )
#   )
#   (generator): Linear(in_features=500, out_features=32768, bias=True)
# )
# [2024-05-30 16:46:06,569 INFO] encoder: 20392000
# [2024-05-30 16:46:06,569 INFO] decoder: 38558768
# [2024-05-30 16:46:06,569 INFO] * number of parameters: 58950768
# [2024-05-30 16:46:06,569 INFO] Trainable parameters = {'torch.float32': 58950768, 'torch.float16': 0, 'torch.uint8': 0, 'torch.int8': 0}
# [2024-05-30 16:46:06,569 INFO] Non trainable parameters = {'torch.float32': 0, 'torch.float16': 0, 'torch.uint8': 0, 'torch.int8': 0}
# [2024-05-30 16:46:06,569 INFO]  * src vocab size = 32768
# [2024-05-30 16:46:06,569 INFO]  * tgt vocab size = 32768
# [2024-05-30 16:46:06,870 INFO] Starting training on GPU: [0]
# [2024-05-30 16:46:06,871 INFO] Start training loop and validate every 500 steps...
# [2024-05-30 16:46:06,871 INFO] Scoring with: None
# [2024-05-30 16:46:09,559 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 1
# [2024-05-30 16:46:12,162 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 1
# [2024-05-30 16:46:14,324 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 2
# [2024-05-30 16:46:14,336 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 2
# [2024-05-30 16:46:16,753 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 3
# [2024-05-30 16:46:16,754 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 3
# [2024-05-30 16:46:19,653 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4
# [2024-05-30 16:46:19,662 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4
# [2024-05-30 16:46:22,214 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 5
# [2024-05-30 16:46:22,219 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 5
# [2024-05-30 16:46:23,888 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 6
# [2024-05-30 16:46:23,906 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 6
# [2024-05-30 16:46:42,231 INFO] Step 50/ 1000; acc: 3.6; ppl: 44059.3; xent: 10.7; lr: 1.00000; sents:    3200; bsz: 1228/1355/64; 1736/1915 tok/s;     35 sec;
# [2024-05-30 16:46:44,580 INFO] Step 100/ 1000; acc: 4.6; ppl: 15154.4; xent: 9.6; lr: 1.00000; sents:    3200; bsz:  955/1042/64; 20334/22196 tok/s;     38 sec;
# [2024-05-30 16:46:48,345 INFO] Step 150/ 1000; acc: 4.1; ppl: 4930.2; xent: 8.5; lr: 1.00000; sents:    3200; bsz: 1490/1639/64; 19786/21768 tok/s;     41 sec;
# [2024-05-30 16:46:51,762 INFO] Step 200/ 1000; acc: 4.2; ppl: 3296.2; xent: 8.1; lr: 1.00000; sents:    3200; bsz: 1392/1530/64; 20370/22382 tok/s;     45 sec;
# [2024-05-30 16:46:55,011 INFO] Step 250/ 1000; acc: 4.9; ppl: 1958.1; xent: 7.6; lr: 1.00000; sents:    3200; bsz: 1322/1452/64; 20355/22356 tok/s;     48 sec;
# [2024-05-30 16:46:58,129 INFO] Step 300/ 1000; acc: 5.5; ppl: 1650.2; xent: 7.4; lr: 1.00000; sents:    3200; bsz: 1293/1415/64; 20731/22687 tok/s;     51 sec;
# [2024-05-30 16:47:00,928 INFO] Step 350/ 1000; acc: 6.1; ppl: 1299.6; xent: 7.2; lr: 1.00000; sents:    3200; bsz: 1158/1264/64; 20703/22585 tok/s;     54 sec;
# [2024-05-30 16:47:04,105 INFO] Step 400/ 1000; acc: 6.5; ppl: 1064.2; xent: 7.0; lr: 1.00000; sents:    3200; bsz: 1321/1456/64; 20789/22914 tok/s;     57 sec;
# [2024-05-30 16:47:07,357 INFO] Step 450/ 1000; acc: 7.4; ppl: 900.3; xent: 6.8; lr: 1.00000; sents:    3200; bsz: 1286/1416/64; 19772/21765 tok/s;     60 sec;
# [2024-05-30 16:47:11,315 INFO] Step 500/ 1000; acc: 7.6; ppl: 807.2; xent: 6.7; lr: 1.00000; sents:    3200; bsz: 1513/1630/64; 19118/20593 tok/s;     64 sec;
# [2024-05-30 16:47:21,802 INFO] valid stats calculation
#                            took: 10.487294912338257 s.
# [2024-05-30 16:47:21,803 INFO] Train perplexity: 2682.39
# [2024-05-30 16:47:21,803 INFO] Train accuracy: 5.47626
# [2024-05-30 16:47:21,803 INFO] Sentences processed: 32000
# [2024-05-30 16:47:21,803 INFO] Average bsz: 1296/1420/64
# [2024-05-30 16:47:21,803 INFO] Validation perplexity: 750.588
# [2024-05-30 16:47:21,803 INFO] Validation accuracy: 5.86345
# [2024-05-30 16:47:21,809 INFO] Saving checkpoint ./Europarl_model_step_500.pt
# [2024-05-30 16:47:25,454 INFO] Step 550/ 1000; acc: 8.9; ppl: 681.5; xent: 6.5; lr: 1.00000; sents:    3200; bsz: 1235/1357/64; 4367/4798 tok/s;     79 sec;
# [2024-05-30 16:47:29,174 INFO] Step 600/ 1000; acc: 9.0; ppl: 637.1; xent: 6.5; lr: 1.00000; sents:    3200; bsz: 1485/1587/64; 19970/21338 tok/s;     82 sec;
# [2024-05-30 16:47:32,855 INFO] Step 650/ 1000; acc: 10.1; ppl: 555.7; xent: 6.3; lr: 1.00000; sents:    3200; bsz: 1516/1683/64; 20589/22858 tok/s;     86 sec;
# [2024-05-30 16:47:36,611 INFO] Step 700/ 1000; acc: 10.4; ppl: 494.3; xent: 6.2; lr: 1.00000; sents:    3200; bsz: 1499/1637/64; 19961/21792 tok/s;     90 sec;
# [2024-05-30 16:47:39,459 INFO] Step 750/ 1000; acc: 12.0; ppl: 415.7; xent: 6.0; lr: 1.00000; sents:    3200; bsz: 1123/1227/64; 19710/21545 tok/s;     93 sec;
# [2024-05-30 16:47:42,272 INFO] Step 800/ 1000; acc: 12.9; ppl: 374.4; xent: 5.9; lr: 1.00000; sents:    3200; bsz: 1158/1281/64; 20594/22773 tok/s;     95 sec;
# [2024-05-30 16:47:46,467 INFO] Step 850/ 1000; acc: 12.9; ppl: 391.8; xent: 6.0; lr: 1.00000; sents:    3168; bsz: 1451/1556/63; 17294/18547 tok/s;    100 sec;
# [2024-05-30 16:47:50,013 INFO] Step 900/ 1000; acc: 13.5; ppl: 341.2; xent: 5.8; lr: 1.00000; sents:    3200; bsz: 1376/1536/64; 19400/21659 tok/s;    103 sec;
# [2024-05-30 16:47:53,250 INFO] Step 950/ 1000; acc: 14.7; ppl: 304.3; xent: 5.7; lr: 1.00000; sents:    3200; bsz: 1312/1495/64; 20270/23103 tok/s;    106 sec;
# [2024-05-30 16:47:56,777 INFO] Step 1000/ 1000; acc: 14.5; ppl: 300.3; xent: 5.7; lr: 1.00000; sents:    3200; bsz: 1505/1657/64; 21344/23491 tok/s;    110 sec;
# [2024-05-30 16:48:07,159 INFO] valid stats calculation
#                            took: 10.381102800369263 s.
# [2024-05-30 16:48:07,159 INFO] Train perplexity: 1049.6
# [2024-05-30 16:48:07,159 INFO] Train accuracy: 8.77439
# [2024-05-30 16:48:07,159 INFO] Sentences processed: 63968
# [2024-05-30 16:48:07,159 INFO] Average bsz: 1331/1461/64
# [2024-05-30 16:48:07,159 INFO] Validation perplexity: 277.263
# [2024-05-30 16:48:07,159 INFO] Validation accuracy: 13.1861
# [2024-05-30 16:48:07,165 INFO] Saving checkpoint ./Europarl_model_step_1000.pt
